# %%
import pandas as pd
import csv

# %%
# Dados

dados = {
     'nome': ['Berry Chic', 'Apple Blossom', 'Peach Couture', 'Lemon Zest', 'Plum & Petal',
             'Cherry Charm', 'Mango Muse', 'Kiwi Couture', 'Grapevine Glam', 'Pineapple Passion',
             'Strawberry Style', 'Blueberry Belle', 'Watermelon Wardrobe', 'Papaya Parade',
             'Fig & Fashion', 'Raspberry Ruche', 'Guava Glamour', 'Lime Luxe', 'Cranberry Chic',
             'Orange Orchard'],
    'descrição' : [
        'Roupas elegantes e modernas inspiradas em frutas vermelhas',
                   'Roupas delicadas e femininas com motivos florais',
                   'Moda couture com um toque de elegância pêssego',
                   'Linha de roupas frescas e vibrantes com acentos cítricos',
                   'Moda sofisticada e refinada com tons de ameixa',
                   'Roupas encantadoras e lúdicas inspiradas em cerejas',
                   'Estilos de moda inspirados em mangas tropicais',
                   'Designs de alta costura com motivos inspirados em kiwi',
                   'Roupas glamorosas com um toque de sedução de videira',
                   'Designs apaixonados e ousados com o charme do abacaxi',
                   'Roupas elegantes e chiques com acentos de morango',
                   'Moda bonita e elegante inspirada em mirtilos',
                   'Um guarda-roupa cheio de roupas divertidas e vibrantes com tema de melancia',
                   'Desfile de roupas modernas e coloridas com motivos de mamão',
                   'Estilos sofisticados com elementos inspirados em figo',
                   'Linha de roupas franzidas e estilosas inspiradas em framboesas',
                   'Designs glamorosos e chiques infundidos com detalhes inspirados em goiaba',
                   'Moda luxuosa e refinada com acentos de verde limão',
                   'Roupas chiques com tons inspirados em cranberry','Designs fashion com tema vibrante de um pomar de laranjas']}

df = pd.DataFrame(dados)
print (df)
df =df.to_csv('marca_descricao.csv', index = False)
# Out:
#                    nome                                          descrição
# 0            Berry Chic  Roupas elegantes e modernas inspiradas em frut...
# 1         Apple Blossom   Roupas delicadas e femininas com motivos florais
# 2         Peach Couture     Moda couture com um toque de elegância pêssego
# 3            Lemon Zest  Linha de roupas frescas e vibrantes com acento...
# 4          Plum & Petal     Moda sofisticada e refinada com tons de ameixa
# 5          Cherry Charm  Roupas encantadoras e lúdicas inspiradas em ce...
# 6            Mango Muse     Estilos de moda inspirados em mangas tropicais
# 7          Kiwi Couture  Designs de alta costura com motivos inspirados...
# 8        Grapevine Glam  Roupas glamorosas com um toque de sedução de v...
# 9     Pineapple Passion  Designs apaixonados e ousados com o charme do ...
# 10     Strawberry Style  Roupas elegantes e chiques com acentos de morango
# ...

# %%
categoria_subcategoria = {

    'categoria': ['Blusa']+ [''] * 15,
    
    'subcategoria' : [
    'Camiseta básica',
    'Blusa regata',
    'Blusa de alça fina',
    'Blusa manga curta',
    'Blusa manga longa',
    'Blusa ombro a ombro',
    'Blusa ciganinha',
    'Blusa cropped',
    'Blusa peplum',
    'Blusa de gola alta',
    'Blusa de gola V',
    'Blusa de gola rolê',
    'Blusa de renda',
    'Blusa de seda',
    'Blusa de tricô',
    'Blusa gola polo'
],

    'descrição' : [
    'Camisetas de algodão, perfeitas para dias quentes ou looks casuais.',
    'Blusas sem mangas, ideais para looks de verão ou atividades esportivas.',
    'Blusas confortáveis, casuais,perfeitas para dias quentes.',
    'Blusas confortáveis, perfeitas para looks casuais.',
    'Blusas femininas com mangas longas, ideais para dias mais frescos ou ocasiões formais.',
    'Blusas ideiais para looks de verão.',
    'Perfeita para os dias mais quentes, proporcionando frescor e elegância.',
    'A blusa cropped é um modelo mais curto que uma camiseta ou regata tradicionais, ou seja, “cortadas".',
    'Blusa elegante com modelagem acinturada e anatômica.',
    'Um toque de sofisticação. Pode ser usada com jeans e couro, para looks casuais e modernos.',
    'O charme da Blusa é o decote V, que faz dela uma peça super coringa e que possibilita criar vários looks versáteis e cheios de estilo.',
    'Confortável e maleável, esta é uma peça coringa da estação.',
    'Uma peça de manga curta repleta de leveza.',
    'Uma blusa leve e fresquinha, com toque de casualidade e delicadeza. ',
    'Uma proposta elegante e atemporal sem perder o conforto. Ideal para os dias mais frios.',
    'Um clássico! Uma mistura da camiseta com a camisa social, mangas curtas e um design mais casual.'
    ]}


df = pd.DataFrame(categoria_subcategoria)
print (df)
df =df.to_csv('categoria_subcategoria.csv', index = False)
# Out:
#    categoria         subcategoria  \
# 0      Blusa      Camiseta básica
# 1                    Blusa regata
# 2              Blusa de alça fina
# 3               Blusa manga curta
# 4               Blusa manga longa
# 5             Blusa ombro a ombro
# 6                 Blusa ciganinha
# 7                   Blusa cropped
# 8                    Blusa peplum
# 9              Blusa de gola alta
# 10                Blusa de gola V
# 11             Blusa de gola rolê
# 12                 Blusa de renda
# 13                  Blusa de seda
# 14                 Blusa de tricô
# 15                Blusa gola polo
#
#                                             descrição
# 0   Camisetas de algodão, perfeitas para dias quen...
# 1   Blusas sem mangas, ideais para looks de verão ...
# 2   Blusas confortáveis, casuais,perfeitas para di...
# 3   Blusas confortáveis, perfeitas para looks casu...
# 4   Blusas femininas com mangas longas, ideais par...
# ...

# %%
categoria_subcategoria = {
    'categoria': ['Blusa'] * 16, 
    
    'subcategoria' : [
        'Camiseta básica',
        'Blusa regata',
        'Blusa de alça fina',
        'Blusa manga curta',
        'Blusa manga longa',
        'Blusa ombro a ombro',
        'Blusa ciganinha',
        'Blusa cropped',
        'Blusa peplum',
        'Blusa de gola alta',
        'Blusa de gola V',
        'Blusa de gola rolê',
        'Blusa de renda',
        'Blusa de seda',
        'Blusa de tricô',
        'Blusa gola polo'
    ],
    
    'descrição' : [
        'Camisetas de algodão, perfeitas para dias quentes ou looks casuais.',
        'Blusas sem mangas, ideais para looks de verão ou atividades esportivas.',
        'Blusas confortáveis, casuais,perfeitas para dias quentes.',
        'Blusas confortáveis, perfeitas para looks casuais.',
        'Blusas femininas com mangas longas, ideais para dias mais frescos ou ocasiões formais.',
        'Blusas ideiais para looks de verão.',
        'Perfeita para os dias mais quentes, proporcionando frescor e elegância.',
        'A blusa cropped é um modelo mais curto que uma camiseta ou regata tradicionais, ou seja, “cortadas".',
        'Blusa elegante com modelagem acinturada e anatômica.',
        'Um toque de sofisticação. Pode ser usada com jeans e couro, para looks casuais e modernos.',
        'O charme da Blusa é o decote V, que faz dela uma peça super coringa e que possibilita criar vários looks versáteis e cheios de estilo.',
        'Confortável e maleável, esta é uma peça coringa da estação.',
        'Uma peça de manga curta repleta de leveza.',
        'Uma blusa leve e fresquinha, com toque de casualidade e delicadeza. ',
        'Uma proposta elegante e atemporal sem perder o conforto. Ideal para os dias mais frios.',
        'Um clássico! Uma mistura da camiseta com a camisa social, mangas curtas e um design mais casual.'
    ]
}

df = pd.DataFrame(categoria_subcategoria)
print(df)
df.to_csv('categoria_subcategoria.csv', index=False)
# Out:
#    categoria         subcategoria  \
# 0      Blusa      Camiseta básica
# 1      Blusa         Blusa regata
# 2      Blusa   Blusa de alça fina
# 3      Blusa    Blusa manga curta
# 4      Blusa    Blusa manga longa
# 5      Blusa  Blusa ombro a ombro
# 6      Blusa      Blusa ciganinha
# 7      Blusa        Blusa cropped
# 8      Blusa         Blusa peplum
# 9      Blusa   Blusa de gola alta
# 10     Blusa      Blusa de gola V
# 11     Blusa   Blusa de gola rolê
# 12     Blusa       Blusa de renda
# 13     Blusa        Blusa de seda
# 14     Blusa       Blusa de tricô
# 15     Blusa      Blusa gola polo
#
#                                             descrição
# 0   Camisetas de algodão, perfeitas para dias quen...
# 1   Blusas sem mangas, ideais para looks de verão ...
# 2   Blusas confortáveis, casuais,perfeitas para di...
# 3   Blusas confortáveis, perfeitas para looks casu...
# 4   Blusas femininas com mangas longas, ideais par...
# ...

# %%
cor = {
    'nome': [
        'Azul',
        'verde',
        'amarelo',
        'vermelho',
        'preto',
        'rosa',
        'branco',
        'cinza',
        'bege',
        'off-white',
        'laranja'
    ],
    'descrição' : [
         'Uma cor que evoca tranquilidade e serenidade.',
         'Uma cor associada à natureza e à renovação.',
         'Uma cor vibrante que simboliza energia e otimismo.',
         'Uma cor apaixonada que transmite calor e vitalidade.',
         'Uma cor clássica que representa elegância e sofisticação.',
         'Uma cor suave que sugere feminilidade e delicadeza.',
         'Uma cor pura que simboliza paz e pureza.',
         'Uma cor neutra e versátil que transmite equilíbrio.',
         'Uma cor suave e discreta que complementa outras cores.',
         'Uma variação suave e cremosa do branco clássico.',
        'Uma cor vibrante que evoca entusiasmo e criatividade.'
    ]}

df = pd.DataFrame(cor)
print(df)
df.to_csv('cor_descricao.csv', index=False)
# Out:
#          nome                                          descrição
# 0        Azul      Uma cor que evoca tranquilidade e serenidade.
# 1       verde        Uma cor associada à natureza e à renovação.
# 2     amarelo  Uma cor vibrante que simboliza energia e otimi...
# 3    vermelho  Uma cor apaixonada que transmite calor e vital...
# 4       preto  Uma cor clássica que representa elegância e so...
# 5        rosa  Uma cor suave que sugere feminilidade e delica...
# 6      branco           Uma cor pura que simboliza paz e pureza.
# 7       cinza  Uma cor neutra e versátil que transmite equilí...
# 8        bege  Uma cor suave e discreta que complementa outra...
# 9   off-white   Uma variação suave e cremosa do branco clássico.
# 10    laranja  Uma cor vibrante que evoca entusiasmo e criati...

# %%
tamanho = {

'P' :['Medidas: Comprimento: 56 cm, Largura: 38 cm.'],
'M' :['Medidas: Comprimento: 57 cm, Largura: 39 cm.'],
'G' :['Medidas: Comprimento: 59 cm, Largura: 41 cm'],
'GG':['Medidas Equivalente ao tamanho 44.'],
'EG':['Extra grande. Medidas equivante ao tamanho 46']
}
    
df = pd.DataFrame(tamanho)
print(df)
df.to_csv('tamanho_descricao.csv', index=False)
# Out:
#                                               P  \
# 0  Medidas: Comprimento: 56 cm, Largura: 38 cm.
#
#                                               M  \
# 0  Medidas: Comprimento: 57 cm, Largura: 39 cm.
#
#                                              G  \
# 0  Medidas: Comprimento: 59 cm, Largura: 41 cm
#
#                                    GG  \
# 0  Medidas Equivalente ao tamanho 44.
#
#                                               EG
# 0  Extra grande. Medidas equivante ao tamanho 46
